# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sharm\OneDrive\Desktop\BigData Arch and Gov\Group Assignment\1.Dataset\Fire_Department_Calls_for_Service.csv")
df.head()
# Out:
# C:\Users\sharm\AppData\Local\Temp\ipykernel_21192\854336587.py:2: DtypeWarning: Columns (19,20,25,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\sharm\OneDrive\Desktop\BigData Arch and Gov\Group Assignment\1.Dataset\Fire_Department_Calls_for_Service.csv")
#    Call Number Unit ID  Incident Number     Call Type   Call Date  Watch Date  \
# 0    221210313     E36         22054955  Outside Fire  05/01/2022  04/30/2022
# 1    220190150     E29         22008871        Alarms  01/19/2022  01/18/2022
# 2    211233271     T07         21053032        Alarms  05/03/2021  05/03/2021
# 3    212933533     B02         21127914        Alarms  10/20/2021  10/20/2021
# 4    221202543     E41         22054815        Alarms  04/30/2022  04/30/2022
#
#             Received DtTm              Entry DtTm           Dispatch DtTm  \
# 0  05/01/2022 02:58:25 AM  05/01/2022 02:59:15 AM  05/01/2022 02:59:25 AM
# ...

# %% [markdown]
# ### Checking if any values in column are null

# %%
print(df.isnull().any())
# Out:
# Call Number                             False
# Unit ID                                 False
# Incident Number                         False
# Call Type                               False
# Call Date                               False
# Watch Date                              False
# Received DtTm                           False
# Entry DtTm                              False
# Dispatch DtTm                           False
# Response DtTm                            True
# On Scene DtTm                            True
# Transport DtTm                           True
# Hospital DtTm                            True
# Call Final Disposition                  False
# Available DtTm                           True
# Address                                 False
# City                                     True
# Zipcode of Incident                      True
# Battalion                               False
# Station Area                             True
# ...

# %%
print(df.isnull().sum())
# Out:
# Call Number                                   0
# Unit ID                                       0
# Incident Number                               0
# Call Type                                     0
# Call Date                                     0
# Watch Date                                    0
# Received DtTm                                 0
# Entry DtTm                                    0
# Dispatch DtTm                                 0
# Response DtTm                            435276
# On Scene DtTm                           1358394
# Transport DtTm                          4518068
# Hospital DtTm                           4655157
# Call Final Disposition                        0
# Available DtTm                            77143
# Address                                       0
# City                                       9090
# Zipcode of Incident                       14859
# Battalion                                     0
# Station Area                               2405
# ...

# %%
### Columns with missing values

Response DtTm                          
On Scene DtTm                            
Transport DtTm                        
Hospital DtTm  
City                                     
Zipcode of Incident   
Station Area                             
Box                                      
Original Priority                        
Priority    
Call Type Group                          
Unit sequence in call dispatch  
case_location                            
Analysis Neighborhoods

# %% [markdown]
# Response DtTm	: Date & Time :	Date and time this unit acknowledges the dispatch and records that the unit is en route to the location of the call.
#
# On Scene DtTm : Date & Time :	Date and time the unit records arriving to the location of the incident.
#
# The missing values of Response DtTm and On Scene DtTm will be filled with Entry DtTm as it is Date and time the 911 operator submits the entry of the initical call information into the CAD system which can be considered to fill the nan values

# %%
df['Response DtTm'].fillna(df['Entry DtTm'], inplace=True)
df['On Scene DtTm'].fillna(df['Entry DtTm'], inplace=True)

# %%
#df['Transport DtTm'].head(25)
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12    01/11/2022 02:04:39 PM
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24    07/13/2021 02:51:27 AM
# Name: Transport DtTm, dtype: object

# %% [markdown]
# Transport DtTm 	: Date & Time :	If this unit is an ambulance, date and time the unit begins the transport unit arrives to hospital
#
# Hospital DtTm  : Date & Time :	If this unit is an ambulance, date and time the unit arrives to the hospital..
#
# The missing values of Transport DtTm and On Hospital DtTm will be filled with Dispatch DtTm DtTm as it is Date and time the 911 operator dispatches this unit to the call which can be considered to fill the nan values

# %%
df['Transport DtTm'].fillna(df['Dispatch DtTm'], inplace=True)
df['Hospital DtTm'].fillna(df['Dispatch DtTm'], inplace=True)

# %%
#df['Transport DtTm'].head(25)
# Out:
# 0     05/01/2022 02:59:25 AM
# 1     01/19/2022 01:44:28 AM
# 2     05/03/2021 09:28:17 PM
# 3     10/20/2021 10:10:07 PM
# 4     04/30/2022 06:37:43 PM
# 5     05/03/2021 04:58:44 PM
# 6     07/13/2021 04:51:17 PM
# 7     10/20/2021 05:48:05 PM
# 8     04/30/2022 02:29:13 PM
# 9     07/13/2021 12:47:21 PM
# 10    01/18/2022 01:59:04 PM
# 11    01/11/2022 01:07:09 PM
# 12    01/11/2022 02:04:39 PM
# 13    01/11/2022 01:02:38 PM
# 14    01/18/2022 12:23:05 PM
# 15    04/30/2022 12:34:15 PM
# 16    07/13/2021 10:05:38 AM
# 17    01/18/2022 10:11:25 AM
# 18    07/28/2022 11:50:13 AM
# 19    07/28/2022 11:39:50 AM
# 20    04/30/2022 09:15:43 AM
# 21    01/18/2022 08:47:08 AM
# 22    05/03/2021 08:12:30 AM
# 23    10/20/2021 08:57:51 AM
# 24    07/13/2021 02:51:27 AM
# Name: Transport DtTm, dtype: object

# %%
#df['Priority'].head(25)
# Out:
# 0     3
# 1     3
# 2     3
# 3     3
# 4     3
# 5     3
# 6     3
# 7     3
# 8     3
# 9     1
# 10    2
# 11    3
# 12    2
# 13    3
# 14    3
# 15    3
# 16    3
# 17    3
# 18    3
# 19    1
# 20    3
# 21    2
# 22    3
# 23    3
# 24    2
# Name: Priority, dtype: object

# %% [markdown]
# Priority and Original Priority are alphanumeric values. So, NaN values can be replaced with mode

# %%
mode_value_priority=df['Priority'].mode()
print(mode_value_priority)
mode_value_og_priority=df['Original Priority'].mode()
print(mode_value_og_priority)
# Out:
# 0    3
# Name: Priority, dtype: object
# 0    3
# Name: Original Priority, dtype: object

# %%
df['Priority'].fillna(value=mode_value_priority, inplace=True)
print(df['Priority'].head(5))
df['Original Priority'].fillna(value=mode_value_og_priority, inplace=True)
print(df['Original Priority'].head(5))
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Priority, dtype: object
# 0    3
# 1    3
# 2    A
# 3    3
# 4    3
# Name: Original Priority, dtype: object

# %% [markdown]
# Since we have address, latitide and longitude co-ordinates are unnecessary and can be dropped. Thus we are dropping drop case_location

# %%
df['case_location'].head(25)
df.drop(['case_location'], axis=1)
# Out:
#          Call Number Unit ID  Incident Number         Call Type   Call Date  \
# 0          221210313     E36         22054955      Outside Fire  05/01/2022
# 1          220190150     E29         22008871            Alarms  01/19/2022
# 2          211233271     T07         21053032            Alarms  05/03/2021
# 3          212933533     B02         21127914            Alarms  10/20/2021
# 4          221202543     E41         22054815            Alarms  04/30/2022
# ...              ...     ...              ...               ...         ...
# 6125493    230313450     T15         23015313            Alarms  01/31/2023
# 6125494    230320055   AM244         23015335  Medical Incident  02/01/2023
# 6125495    230181881    QRV1         23008833  Medical Incident  01/18/2023
# 6125496    230181881   AM108         23008833  Medical Incident  01/18/2023
# 6125497    230180743   SCRT3         23008682  Medical Incident  01/18/2023
#
# ...

# %% [markdown]
# Call Type Group : Call types are divided into four main groups: Fire, Alarm, Potential Life Threatening and Non-Life Threatening. We fill the missing values with type "unknown" to eliminate NaN

# %%
df['Call Type Group'].fillna("Unknown")
# Out:
# 0                             Fire
# 1                            Alarm
# 2                            Alarm
# 3                            Alarm
# 4                            Alarm
# 5                            Alarm
# 6                            Alarm
# 7                            Alarm
# 8                            Alarm
# 9             Non Life-threatening
# 10            Non Life-threatening
# 11                           Alarm
# 12    Potentially Life-Threatening
# 13                            Fire
# 14                           Alarm
# 15                            Fire
# 16                           Alarm
# 17                           Alarm
# 18                           Alarm
# 19                             NaN
# 20                           Alarm
# 21            Non Life-threatening
# 22                           Alarm
# 23                           Alarm
# 24    Potentially Life-Threatening
# Name: Call Type Group, dtype: object

# %%
df['Call Type Group'].fillna("Unknown")
# Out:
# 0                             Fire
# 1                            Alarm
# 2                            Alarm
# 3                            Alarm
# 4                            Alarm
# 5                            Alarm
# 6                            Alarm
# 7                            Alarm
# 8                            Alarm
# 9             Non Life-threatening
# 10            Non Life-threatening
# 11                           Alarm
# 12    Potentially Life-Threatening
# 13                            Fire
# 14                           Alarm
# 15                            Fire
# 16                           Alarm
# 17                           Alarm
# 18                           Alarm
# 19                         Unknown
# 20                           Alarm
# 21            Non Life-threatening
# 22                           Alarm
# 23                           Alarm
# 24    Potentially Life-Threatening
# 25            Non Life-threatening
# 26            Non Life-threatening
# ...
